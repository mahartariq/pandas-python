# %%
import pandas as pd

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.rename(columns = {'Colors Reported':'Colors_Reported', 'Shape Reported':'Shape_Reported'}, inplace = True)

# %%
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %%
ufo_cols = ['City_Name', 'Colours_Reported', 'Shape_Reported','State_C','Date_Time']

# %%
ufo.columns = ufo_cols

# %%
ufo.head()
# Out:
#               City_Name Colours_Reported Shape_Reported State_C  \
# 0                Ithaca              NaN       TRIANGLE      NY
# 1           Willingboro              NaN          OTHER      NJ
# 2               Holyoke              NaN           OVAL      CO
# 3               Abilene              NaN           DISK      KS
# 4  New York Worlds Fair              NaN          LIGHT      NY
#
#          Date_Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 2  2/15/1931 14:00
# 3   6/1/1931 13:00
# 4  4/18/1933 19:00

# %%
ufo.columns
# Out:
# Index(['City_Name', 'Colours_Reported', 'Shape_Reported', 'State_C',
#        'Date_Time'],
#       dtype='object')

# %%
ufo = pd.read_csv('http://bit.ly/uforeports', names = ufo_cols, header=0)

# %%
ufo.head()
# Out:
#               City_Name Colours_Reported Shape_Reported State_C  \
# 0                Ithaca              NaN       TRIANGLE      NY
# 1           Willingboro              NaN          OTHER      NJ
# 2               Holyoke              NaN           OVAL      CO
# 3               Abilene              NaN           DISK      KS
# 4  New York Worlds Fair              NaN          LIGHT      NY
#
#          Date_Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 2  2/15/1931 14:00
# 3   6/1/1931 13:00
# 4  4/18/1933 19:00

# %%
ufo = pd.read_csv('http://bit.ly/uforeports', names = ufo_cols)

# %%
ufo.head()
# Out:
#      City_Name Colours_Reported  Shape_Reported State_C        Date_Time
# 0         City  Colors Reported  Shape Reported   State             Time
# 1       Ithaca              NaN        TRIANGLE      NY   6/1/1930 22:00
# 2  Willingboro              NaN           OTHER      NJ  6/30/1930 20:00
# 3      Holyoke              NaN            OVAL      CO  2/15/1931 14:00
# 4      Abilene              NaN            DISK      KS   6/1/1931 13:00

# %%
ufo = pd.read_csv('http://bit.ly/uforeports', names = ufo_cols, header=0)
ufo.head()
# Out:
#               City_Name Colours_Reported Shape_Reported State_C  \
# 0                Ithaca              NaN       TRIANGLE      NY
# 1           Willingboro              NaN          OTHER      NJ
# 2               Holyoke              NaN           OVAL      CO
# 3               Abilene              NaN           DISK      KS
# 4  New York Worlds Fair              NaN          LIGHT      NY
#
#          Date_Time
# 0   6/1/1930 22:00
# 1  6/30/1930 20:00
# 2  2/15/1931 14:00
# 3   6/1/1931 13:00
# 4  4/18/1933 19:00

# %%
ufo.columns
# Out:
# Index(['City_Name', 'Colours_Reported', 'Shape_Reported', 'State_C',
#        'Date_Time'],
#       dtype='object')

# %%
ufo.columns = ufo.columns.str.replace('_',' ')

# %%
ufo.columns
# Out:
# Index(['City Name', 'Colours Reported', 'Shape Reported', 'State C',
#        'Date Time'],
#       dtype='object')

# %%
ufo.columns = ufo.columns.str.replace(' ','_')

# %%
ufo.columns
# Out:
# Index(['City_Name', 'Colours_Reported', 'Shape_Reported', 'State_C',
#        'Date_Time'],
#       dtype='object')
