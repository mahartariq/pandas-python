# %%
import pandas as pd

# %%
pd.read_table('Sample.tsv')
# Out:
#   Some parameter  Other parameter  Last parameter
# 0          CONST           123456           12.45

# %%
pd.read_table('http://bit.ly/chiporders')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
orders = pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
pd.read_table('http://bit.ly/movieusers')
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %%
pd.read_table('http://bit.ly/movieusers', sep='|')
# Out:
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# ..   ...  .. ..            ...    ...
# 937  939  26  F        student  33319
# 938  940  32  M  administrator  02215
# 939  941  20  M        student  97229
# 940  942  48  F      librarian  78209
# 941  943  22  M        student  77841
#
# [942 rows x 5 columns]

# %%
pd.read_table('http://bit.ly/movieusers', sep = '|', header = None)
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
user_cols = ['id','age','gender','profession','zip_code']

# %%
pd.read_table('http://bit.ly/movieusers', sep='|', header = None, names = user_cols)
# Out:
#       id  age gender     profession zip_code
# 0      1   24      M     technician    85711
# 1      2   53      F          other    94043
# 2      3   23      M         writer    32067
# 3      4   24      M     technician    43537
# 4      5   33      F          other    15213
# ..   ...  ...    ...            ...      ...
# 938  939   26      F        student    33319
# 939  940   32      M  administrator    02215
# 940  941   20      M        student    97229
# 941  942   48      F      librarian    78209
# 942  943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
user_data = pd.read_table('http://bit.ly/movieusers', sep='|', header = None, names = user_cols)

# %%
user_data.head()
# Out:
#    id  age gender  profession zip_code
# 0   1   24      M  technician    85711
# 1   2   53      F       other    94043
# 2   3   23      M      writer    32067
# 3   4   24      M  technician    43537
# 4   5   33      F       other    15213

# %%
pd.read_table('http://bit.ly/movieusers', sep='|', header = None, names = user_cols, skiprows = 2)
# Out:
#       id  age gender     profession zip_code
# 0      3   23      M         writer    32067
# 1      4   24      M     technician    43537
# 2      5   33      F          other    15213
# 3      6   42      M      executive    98101
# 4      7   57      M  administrator    91344
# ..   ...  ...    ...            ...      ...
# 936  939   26      F        student    33319
# 937  940   32      M  administrator    02215
# 938  941   20      M        student    97229
# 939  942   48      F      librarian    78209
# 940  943   22      M        student    77841
#
# [941 rows x 5 columns]

# %%
pd.read_table('http://bit.ly/movieusers', sep='|', header = None, names = user_cols, skipfooter = 2)
# Out:
# C:\Users\M TARYK\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#       id  age gender     profession zip_code
# 0      1   24      M     technician    85711
# 1      2   53      F          other    94043
# 2      3   23      M         writer    32067
# 3      4   24      M     technician    43537
# 4      5   33      F          other    15213
# ..   ...  ...    ...            ...      ...
# 936  937   48      M       educator    98072
# 937  938   38      F     technician    55038
# 938  939   26      F        student    33319
# 939  940   32      M  administrator    02215
# 940  941   20      M        student    97229
#
# [941 rows x 5 columns]

# %%
pd.read_table('Sample.tsv', header = None, sep = '|')
# Out:
#                                                  0
# 0  Some parameter\tOther parameter\tLast parameter
# 1                             CONST\t123456\t12.45

# %%
pd.read_table('Sample.tsv', sep = '|')
# Out:
#   Some parameter\tOther parameter\tLast parameter
# 0                            CONST\t123456\t12.45

# %%
pd.read_table('Sample.tsv')
# Out:
#   Some parameter  Other parameter  Last parameter
# 0          CONST           123456           12.45
